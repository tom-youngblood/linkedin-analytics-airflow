# %%
import pandas as pd
import logging

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('logs/testing.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# %%
scrape_posts_by_profile_df = pd.read_csv("../data/function_outputs/scrape_posts_by_profile.csv")
prepare_media_enrichment_data_df = pd.read_csv("../data/function_outputs/prepare_media_enrichment_data.csv")

# %%
scrape_posts_by_profile_df.head(2).to_json("../data/function_outputs/scrape_posts_by_profile_df_head_2.json")

# %%
prepare_media_enrichment_data_df.head(2).to_json("../data/function_outputs/prepare_media_enrichment_data_df_head_2.json")

# %%
merged = finalize_enrichment_output(scrape_posts_by_profile_df, prepare_media_enrichment_data_df)
# Out:
# 2025-06-23 14:13:48,062 - __main__ - INFO - Performing merge...
# 2025-06-23 14:13:48,068 - __main__ - INFO - Merge complete:
#                     urn                             full_urn  \
# 0   7342952121291427841  urn:li:activity:7342952121291427841
# 1   7341941942844301312  urn:li:activity:7341941942844301312
# 2   7341864942129582080   urn:li:ugcPost:7341540982041079809
# 3   7340415388322586627   urn:li:ugcPost:7338633005688610817
# 4   7339320686634573826   urn:li:ugcPost:7337992009300832256
# 5   7338603440203304961   urn:li:ugcPost:7336534923861733376
# 6   7337878685523316736  urn:li:activity:7337878685523316736
# 7   7336861550541946880  urn:li:activity:7336861550541946880
# 8   7336436667722977282   urn:li:ugcPost:7336432866420998145
# 9   7336110656061919233   urn:li:ugcPost:7336107695881560068
# 10  7335368709198282754   urn:li:ugcPost:7335368599638867969
# 11  7334264137276866562   urn:li:ugcPost:7334263736330817536
# ...

# %%
merged
# Out:
#                     urn                             full_urn  \
# 0   7342952121291427841  urn:li:activity:7342952121291427841
# 1   7341941942844301312  urn:li:activity:7341941942844301312
# 2   7341864942129582080   urn:li:ugcPost:7341540982041079809
# 3   7340415388322586627   urn:li:ugcPost:7338633005688610817
# 4   7339320686634573826   urn:li:ugcPost:7337992009300832256
# 5   7338603440203304961   urn:li:ugcPost:7336534923861733376
# 6   7337878685523316736  urn:li:activity:7337878685523316736
# 7   7336861550541946880  urn:li:activity:7336861550541946880
# 8   7336436667722977282   urn:li:ugcPost:7336432866420998145
# 9   7336110656061919233   urn:li:ugcPost:7336107695881560068
# 10  7335368709198282754   urn:li:ugcPost:7335368599638867969
# 11  7334264137276866562   urn:li:ugcPost:7334263736330817536
# 12  7333994650879348736   urn:li:ugcPost:7333994204345286657
# 13  7333952681457188864   urn:li:ugcPost:7333952679833948161
#
# ...

# %%
prepare_media_enrichment_data_df.columns
# Out:
# Index(['post_url', 'media_type', 'duration', 'mime_type', 'thumbnail',
#        'video_url', 'image_url', 'post', 'author', 'media', 'stats'],
#       dtype='object')
